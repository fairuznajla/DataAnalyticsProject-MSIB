# %%
import pandas as pd

# %%
foodsales = pd.read_csv('FoodSales.csv')
foodsales
# Out:
#       OrderDate  order_date Region         City  Category         Product  \
# 0    01/01/2020  01/01/2020   East       Boston      Bars          Carrot
# 1    04/01/2020  04/01/2020   East       Boston  Crackers     Whole Wheat
# 2    07/01/2020  07/01/2020   West  Los Angeles   Cookies  Chocolate Chip
# 3    10/01/2020  10/01/2020   East     New York   Cookies  Chocolate Chip
# 4    13/01/2020  13/01/2020   East       Boston   Cookies       Arrowroot
# ..          ...         ...    ...          ...       ...             ...
# 239  18/12/2021  18/12/2021   East       Boston   Cookies       Arrowroot
# 240  21/12/2021  21/12/2021   East       Boston   Cookies  Chocolate Chip
# 241  24/12/2021  24/12/2021   East       Boston  Crackers     Whole Wheat
# 242  27/12/2021  27/12/2021   West  Los Angeles      Bars            Bran
# 243  30/12/2021  30/12/2021   West  Los Angeles   Cookies  Oatmeal Raisin
#
#      Quantity  UnitPrice  TotalPrice
# 0          33       1.77       58.41
# ...

# %%
# 1 
# tampilkan informasi tipe data tiap kolom

foodsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   244 non-null    object
#  1   order_date  244 non-null    object
#  2   Region      244 non-null    object
#  3   City        244 non-null    object
#  4   Category    244 non-null    object
#  5   Product     244 non-null    object
#  6   Quantity    244 non-null    int64
#  7   UnitPrice   244 non-null    float64
#  8   TotalPrice  244 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 17.3+ KB

# %%
# 2
# tampilkan semua data yang berasal dari City Los Angeles dan Quantity kurang dari 90

foodsales[(foodsales['City']=='Los Angeles') & (foodsales['Quantity'] < 90)]
# Out:
#       OrderDate  order_date Region         City  Category         Product  \
# 2    07/01/2020  07/01/2020   West  Los Angeles   Cookies  Chocolate Chip
# 7    22/01/2020  22/01/2020   West  Los Angeles      Bars          Carrot
# 13   09/02/2020  09/02/2020   West  Los Angeles      Bars          Carrot
# 18   24/02/2020  24/02/2020   West  Los Angeles      Bars            Bran
# 19   27/02/2020  27/02/2020   West  Los Angeles   Cookies  Oatmeal Raisin
# 24   14/03/2020  14/03/2020   West  Los Angeles   Cookies  Chocolate Chip
# 30   01/04/2020  01/04/2020   West  Los Angeles      Bars          Carrot
# 31   04/04/2020  04/04/2020   West  Los Angeles    Snacks    Potato Chips
# 37   22/04/2020  22/04/2020   West  Los Angeles      Bars          Carrot
# 43   10/05/2020  10/05/2020   West  Los Angeles      Bars          Carrot
# 44   13/05/2020  13/05/2020   West  Los Angeles  Crackers     Whole Wheat
# 58   24/06/2020  24/06/2020   West  Los Angeles    Snacks    Potato Chips
# ...

# %%
# 2
# tampilkan semua data yang berasal dari City Los Angeles dan Quantity kurang dari 90

foodsales[(foodsales.iloc[:,3]=='Los Angeles') & (foodsales.iloc[:,6] < 90)]
# Out:
#       OrderDate  order_date Region         City  Category         Product  \
# 2    07/01/2020  07/01/2020   West  Los Angeles   Cookies  Chocolate Chip
# 7    22/01/2020  22/01/2020   West  Los Angeles      Bars          Carrot
# 13   09/02/2020  09/02/2020   West  Los Angeles      Bars          Carrot
# 18   24/02/2020  24/02/2020   West  Los Angeles      Bars            Bran
# 19   27/02/2020  27/02/2020   West  Los Angeles   Cookies  Oatmeal Raisin
# 24   14/03/2020  14/03/2020   West  Los Angeles   Cookies  Chocolate Chip
# 30   01/04/2020  01/04/2020   West  Los Angeles      Bars          Carrot
# 31   04/04/2020  04/04/2020   West  Los Angeles    Snacks    Potato Chips
# 37   22/04/2020  22/04/2020   West  Los Angeles      Bars          Carrot
# 43   10/05/2020  10/05/2020   West  Los Angeles      Bars          Carrot
# 44   13/05/2020  13/05/2020   West  Los Angeles  Crackers     Whole Wheat
# 58   24/06/2020  24/06/2020   West  Los Angeles    Snacks    Potato Chips
# ...

# %%
# 3
# Product apakah yang paling sering dibeli di region west?

region_west = foodsales[foodsales.Region=='West']
best_seller = region_west.groupby('Product')['Quantity'].sum()
best_seller.sort_values(ascending=False).head(1)
# Out:
# Product
# Carrot    1786
# Name: Quantity, dtype: int64

# %%
# 4
# Lakukan iterasi untuk membandingkan apakah nilai transaksi pada indeks tersebut lebih besar dibandingkan dengan index sebelumnya, dimulai dari index 1 (bukan 0)

foodsales['lebih_besar']

for row, col in foodsales.iterrows():
    if row > 0:
        if col['TotalPrice'] > foodsales.at[row - 1, 'TotalPrice']:
            foodsales.at[row, 'lebih_besar'] = True
print(foodsales[['TotalPrice','lebih_besar']])
# Out:
#      TotalPrice  lebih_besar
# 0         58.41        False
# 1        303.63         True
# 2        108.46        False
# 3        153.34         True
# 4         82.84        False
# ..          ...          ...
# 239       74.12        False
# 240      458.15         True
# 241      104.70        False
# 242       56.10        False
# 243      124.96         True
#
# [244 rows x 2 columns]
